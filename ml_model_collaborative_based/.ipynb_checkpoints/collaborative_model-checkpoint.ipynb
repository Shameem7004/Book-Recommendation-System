# %%
import pandas as pd
import numpy as np
import os
from scipy.sparse import csr_matrix
from sklearn.neighbors import NearestNeighbors
import pickle

# %%
# --- Step 1: Load the Cleaned Artifacts ---
# For this model, we need all three core artifacts.
books_df = pd.read_pickle('../artifacts/books.pkl')
ratings_df = pd.read_pickle('../artifacts/ratings.pkl')
users_df = pd.read_pickle('../artifacts/users.pkl')

# %%
print(books_df.shape)
print(ratings_df.shape)
print(users_df.shape)
# Out:
# (269215, 7)
# (1149780, 3)
# (105283, 3)

# %%
# --- Step 2: Merge DataFrames ---
# To work with the data effectively, we'll merge ratings_df and books_df.
# We only need the title and ISBN from books_df to merge

ratings_with_books_df = ratings_df.merge(books_df[['ISBN', 'Book-Title', 'Book-Author']], on='ISBN')
ratings_with_books_df
# Out:
#          User-ID        ISBN  Book-Rating  \
# 0         276725  034545104X            0
# 1         276726  0155061224            5
# 2         276727  0446520802            0
# 3         276729  052165615X            3
# 4         276729  0521795028            6
# ...          ...         ...          ...
# 1025112   276704  0876044011            0
# 1025113   276704  1563526298            9
# 1025114   276706  0679447156            0
# 1025115   276709  0515107662           10
# 1025116   276721  0590442449           10
#
#                                                 Book-Title        Book-Author
# 0                                     Flesh Tones: A Novel         M. J. Rose
# 1                                         Rites of Passage         Judith Rae
# 2                                             The Notebook    Nicholas Sparks
# 3                                           Help!: Level 1      Philip Prowse
# 4        The Amsterdam Connection : Level 4 (Cambridge ...        Sue Leather
# ...                                                    ...                ...
# 1025112  Edgar Cayce on the Akashic Records: The Book o...  Kevin J. Todeschi
# 1025113  Get Clark Smart : The Ultimate Guide for the S...       Clark Howard
# 1025114  Eight Weeks to Optimum Health: A Proven Progra...        Andrew Weil
# 1025115   The Sherbrooke Bride (Bride Trilogy (Paperback))  Catherine Coulter
# 1025116                                  Fourth Grade Rats     Jerry Spinelli
#
# [1025117 rows x 5 columns]

# %%
# --- Step 3: Filter the Data for Model Stability ---
# The dataset is very large and sparse. To build a reliable model, we'll filter it:
# 1. Keep users who have rated at least 200 books (experienced users).
# 2. Keep books that have been rated at least 50 times (popular books).

# Count ratings per user
user_rating_counts = ratings_with_books_df.groupby('User-ID').count()['Book-Rating']
user_rating_counts
# Out:
# User-ID
# 2          1
# 8         17
# 9          3
# 10         1
# 12         1
#           ..
# 278846     1
# 278849     4
# 278851    22
# 278852     1
# 278854     8
# Name: Book-Rating, Length: 91784, dtype: int64

# %%
# Get a list of user id of the users who have rated >= 200 books
experienced_users = user_rating_counts[user_rating_counts >= 200].index
experienced_users
# Out:
# Index([   254,   2276,   2766,   2977,   3363,   4017,   4385,   6251,   6323,
#          6543,
#        ...
#        271705, 273979, 274004, 274061, 274301, 274308, 275970, 277427, 277639,
#        278418],
#       dtype='int64', name='User-ID', length=812)

# %%
# Filter the main dataframe to keep only these experienced users
filtered_ratings_by_user = ratings_with_books_df[ratings_with_books_df['User-ID'].isin(experienced_users)]
filtered_ratings_by_user
# Out:
#          User-ID        ISBN  Book-Rating  \
# 1145      277427  002542730X           10
# 1146      277427  0026217457            0
# 1147      277427  003008685X            8
# 1148      277427  0030615321            0
# 1149      277427  0060002050            0
# ...          ...         ...          ...
# 1023355   275970  1931868123            0
# 1023356   275970  3411086211           10
# 1023357   275970  3829021860            0
# 1023358   275970  4770019572            0
# 1023359   275970  9626340762            8
#
#                                                 Book-Title  \
# 1145     Politically Correct Bedtime Stories: Modern Ta...
# 1146                    Vegetarian Times Complete Cookbook
# 1147                                              Pioneers
# 1148      Ask for May, Settle for June (A Doonesbury book)
# 1149                     On a Wicked Dawn (Cynster Novels)
# ...                                                    ...
# 1023355  There's a Porcupine in My Outhouse: Misadventu...
# 1023356                                         Die Biene.
# 1023357                                     The Penis Book
# 1023358                                            Musashi
# 1023359  Northanger Abbey (Classic Literature with Clas...
#
#                            Book-Author
# 1145                 James Finn Garner
# 1146                        Lucy  Moll
# 1147             James Fenimore Cooper
# 1148                     G. B. Trudeau
# 1149                 Stephanie Laurens
# ...                                ...
# 1023355                   Mike Tougias
# 1023356  Sybil GrÃ?Â¤fin SchÃ?Â¶nfeldt
# 1023357                   Joseph Cohen
# 1023358                 Eiji Yoshikawa
# 1023359                    Jane Austen
#
# [471668 rows x 5 columns]

# %%
duplicates = filtered_ratings_by_user[filtered_ratings_by_user.duplicated(subset=['Book-Title', 'Book-Author'], keep=False)]

# Show some results
# print(duplicates.head())

# Optional: sort them to see duplicates together
duplicates_sorted = duplicates.sort_values(by=['Book-Title', 'Book-Author'])
duplicates_sorted
# Out:
#         User-ID        ISBN  Book-Rating  \
# 142271    35859  0590567330            0
# 356290    96448  0590567330            9
# 100598    26544  006250746X            9
# 660275   179744  006250746X            6
# 757471   205980  006250746X           10
# ...         ...         ...          ...
# 50141     11676  3518120549            8
# 587357   160032  3518120549            0
# 49681     11676  3257700512            0
# 587207   160032  3257700512            0
# 637643   173632  3257700512            0
#
#                                                Book-Title          Book-Author
# 142271   A Light in the Storm: The Civil War Diary of ...          Karen Hesse
# 356290   A Light in the Storm: The Civil War Diary of ...          Karen Hesse
# 100598   Earth Prayers From around the World: 365 Pray...    Elizabeth Roberts
# 660275   Earth Prayers From around the World: 365 Pray...    Elizabeth Roberts
# 757471   Earth Prayers From around the World: 365 Pray...    Elizabeth Roberts
# ...                                                   ...                  ...
# 50141                              Ã?Â?ber das Fernsehen.      Pierre Bourdieu
# 587357                             Ã?Â?ber das Fernsehen.      Pierre Bourdieu
# 49681   Ã?Â?ber die Pflicht zum Ungehorsam gegen den S...  Henry David Thoreau
# 587207  Ã?Â?ber die Pflicht zum Ungehorsam gegen den S...  Henry David Thoreau
# 637643  Ã?Â?ber die Pflicht zum Ungehorsam gegen den S...  Henry David Thoreau
#
# [376562 rows x 5 columns]

# %%
# Grouping by both title and author for accuracy, then count the rows and reset the index
book_rating_counts = filtered_ratings_by_user.groupby(['Book-Title', 'Book-Author']).size().reset_index(name='num_book_ratings')
book_rating_counts
# Out:
#                                                Book-Title  \
# 0        A Light in the Storm: The Civil War Diary of ...
# 1                                   Always Have Popsicles
# 2                    Apple Magic (The Collector's series)
# 3        Beyond IBM: Leadership Marketing and Finance ...
# 4        Clifford Visita El Hospital (Clifford El Gran...
# ...                                                   ...
# 161536                             Ã?Â?ber das Fernsehen.
# 161537  Ã?Â?ber die Pflicht zum Ungehorsam gegen den S...
# 161538                                      Ã?Â?lpiraten.
# 161539                              Ã?Â?stlich der Berge.
# 161540                                  Ã?Â?thique en toc
#
#                       Book-Author  num_book_ratings
# 0                     Karen Hesse                 2
# 1                  Rebecca Harvin                 1
# 2                Martina Boudreau                 1
# 3                      Lou Mobley                 1
# 4                 Norman Bridwell                 1
# ...                           ...               ...
# 161536            Pierre Bourdieu                 2
# 161537        Henry David Thoreau                 3
# 161538  Janwillem van de Wetering                 1
# 161539             David Guterson                 1
# 161540           Didier Daeninckx                 1
#
# [161541 rows x 3 columns]

# %%
book_rating_counts.duplicated(subset=['Book-Title', 'Book-Author']).sum()
# Out:
# np.int64(0)

# %%
# Get a list of popular books (where count is >= 50)
popular_books_df = book_rating_counts[book_rating_counts['num_book_ratings'] >= 50]
popular_books_df
# Out:
#                                                Book-Title         Book-Author  \
# 487                                                  1984       George Orwell
# 521                                   1st to Die: A Novel     James Patterson
# 660                                            2nd Chance     James Patterson
# 805                                             4 Blondes    Candace Bushnell
# 1131                                   A Bend in the Road     Nicholas Sparks
# ...                                                   ...                 ...
# 160352                                    Year of Wonders    Geraldine Brooks
# 160576                                   You Belong To Me  Mary Higgins Clark
# 161210  Zen and the Art of Motorcycle Maintenance: An ...       ROBERT PIRSIG
# 161355                                               Zoya      Danielle Steel
# 161438                                \O\" Is for Outlaw"         SUE GRAFTON
#
#         num_book_ratings
# 487                   71
# 521                  160
# 660                  122
# 805                   70
# 1131                 113
# ...                  ...
# 160352                57
# 160576                55
# 161210                55
# 161355                59
# 161438                68
#
# [628 rows x 3 columns]

# %%
filtered_ratings_by_user
# Out:
#          User-ID        ISBN  Book-Rating  \
# 1145      277427  002542730X           10
# 1146      277427  0026217457            0
# 1147      277427  003008685X            8
# 1148      277427  0030615321            0
# 1149      277427  0060002050            0
# ...          ...         ...          ...
# 1023355   275970  1931868123            0
# 1023356   275970  3411086211           10
# 1023357   275970  3829021860            0
# 1023358   275970  4770019572            0
# 1023359   275970  9626340762            8
#
#                                                 Book-Title  \
# 1145     Politically Correct Bedtime Stories: Modern Ta...
# 1146                    Vegetarian Times Complete Cookbook
# 1147                                              Pioneers
# 1148      Ask for May, Settle for June (A Doonesbury book)
# 1149                     On a Wicked Dawn (Cynster Novels)
# ...                                                    ...
# 1023355  There's a Porcupine in My Outhouse: Misadventu...
# 1023356                                         Die Biene.
# 1023357                                     The Penis Book
# 1023358                                            Musashi
# 1023359  Northanger Abbey (Classic Literature with Clas...
#
#                            Book-Author
# 1145                 James Finn Garner
# 1146                        Lucy  Moll
# 1147             James Fenimore Cooper
# 1148                     G. B. Trudeau
# 1149                 Stephanie Laurens
# ...                                ...
# 1023355                   Mike Tougias
# 1023356  Sybil GrÃ?Â¤fin SchÃ?Â¶nfeldt
# 1023357                   Joseph Cohen
# 1023358                 Eiji Yoshikawa
# 1023359                    Jane Austen
#
# [471668 rows x 5 columns]

# %%
# Filter the ratings dataframe again to keep only ratings for these popular books
final_ratings = filtered_ratings_by_user.merge(popular_books_df[['Book-Title', 'Book-Author']], on=['Book-Title', 'Book-Author'])
final_ratings
# Out:
#        User-ID        ISBN  Book-Rating  \
# 0       277427  002542730X           10
# 1       277427  0060930535            0
# 2       277427  0060934417            0
# 3       277427  0061009059            9
# 4       277427  006440188X            0
# ...        ...         ...          ...
# 52051   275970  1400031354            0
# 52052   275970  1400031362            0
# 52053   275970  1573229725            0
# 52054   275970  1586210661            9
# 52055   275970  1586212230            0
#
#                                               Book-Title  \
# 0      Politically Correct Bedtime Stories: Modern Ta...
# 1                          The Poisonwood Bible: A Novel
# 2                                     Bel Canto: A Novel
# 3      One for the Money (Stephanie Plum Novels (Pape...
# 4                                      The Secret Garden
# ...                                                  ...
# 52051  Tears of the Giraffe (No.1 Ladies Detective Ag...
# 52052  Morality for Beautiful Girls (No.1 Ladies Dete...
# 52053                                        Fingersmith
# 52054                             Me Talk Pretty One Day
# 52055                                              Naked
#
#                    Book-Author
# 0            James Finn Garner
# 1           Barbara Kingsolver
# 2                 Ann Patchett
# 3              Janet Evanovich
# 4      Frances Hodgson Burnett
# ...                        ...
# 52051   Alexander McCall Smith
# 52052   Alexander McCall Smith
# 52053             Sarah Waters
# 52054            David Sedaris
# 52055            David Sedaris
#
# [52056 rows x 5 columns]

# %%
duplicates = final_ratings[final_ratings.duplicated(subset=['Book-Title', 'Book-Author'], keep=False)]

# sort them to see duplicates together
duplicates_sorted = duplicates.sort_values(by=['Book-Title', 'Book-Author'])
duplicates_sorted
# Out:
#        User-ID        ISBN  Book-Rating           Book-Title    Book-Author
# 276        254  0451524934            9                 1984  George Orwell
# 1141      7346  0451519841            8                 1984  George Orwell
# 2176     11676  0451519841            0                 1984  George Orwell
# 2177     11676  0451524934            0                 1984  George Orwell
# 2180     11676  0452262933           10                 1984  George Orwell
# ...        ...         ...          ...                  ...            ...
# 50632   268032  0449003787            0  \O\" Is for Outlaw"    SUE GRAFTON
# 50779   268330  0449003787            0  \O\" Is for Outlaw"    SUE GRAFTON
# 50971   269566  0449003787            0  \O\" Is for Outlaw"    SUE GRAFTON
# 51094   269719  0449003787            0  \O\" Is for Outlaw"    SUE GRAFTON
# 51832   274301  0449003787            8  \O\" Is for Outlaw"    SUE GRAFTON
#
# [52056 rows x 5 columns]

# %%
final_ratings.duplicated(subset=['Book-Title', 'Book-Author']).sum()
# Out:
# np.int64(51428)

# %%
# --- Step 4: Create the User-Item Interaction Matrix ---
# We'll pivot the table so that rows are book titles and columns are user IDs.
# The values will be the ratings. This is the "utility matrix".

# If a user rated the same book multiple times, take the mean of their ratings rather than simply dropping duplicates.
final_ratings = final_ratings.groupby(['User-ID', 'Book-Title', 'Book-Author'])['Book-Rating'].mean().reset_index()
final_ratings
# Out:
#        User-ID                                         Book-Title  \
# 0          254                                               1984
# 1          254                                 A Bend in the Road
# 2          254                                     ANGELA'S ASHES
# 3          254                                      American Gods
# 4          254                    Angela's Ashes (MMP) : A Memoir
# ...        ...                                                ...
# 50692   278418                                     Watership Down
# 50693   278418                              Welcome to Temptation
# 50694   278418  Where the Heart Is (Oprah's Book Club (Paperba...
# 50695   278418                           Where the Red Fern Grows
# 50696   278418                          Whirlwind (Tyler, Book 1)
#
#            Book-Author  Book-Rating
# 0        George Orwell          9.0
# 1      Nicholas Sparks          0.0
# 2        Frank McCourt          0.0
# 3          Neil Gaiman         10.0
# 4        Frank McCourt          0.0
# ...                ...          ...
# 50692    Richard Adams          0.0
# 50693  Jennifer Crusie          0.0
# 50694     Billie Letts          0.0
# 50695     Wilson Rawls          0.0
# 50696     Nancy Martin          0.0
#
# [50697 rows x 4 columns]

# %%
final_ratings.duplicated(subset=['User-ID','Book-Title', 'Book-Author']).sum()
# Out:
# np.int64(0)

# %%
pivot_table = final_ratings.pivot_table(index='Book-Title', columns='User-ID', values='Book-Rating')
pivot_table
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN    10.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     0.0     NaN     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# User-ID                                             2977    3363    4017    \
# Book-Title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        7.0     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     0.0     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# User-ID                                             4385    6251    6323    \
# Book-Title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     NaN
# 4 Blondes                                              NaN     0.0     NaN
# A Bend in the Road                                     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     0.0     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# User-ID                                             6543    ...  271705  \
# Book-Title                                                  ...
# 1984                                                   NaN  ...    10.0
# 1st to Die: A Novel                                    9.0  ...     NaN
# 2nd Chance                                             0.0  ...     NaN
# 4 Blondes                                              NaN  ...     NaN
# A Bend in the Road                                     NaN  ...     NaN
# ...                                                    ...  ...     ...
# Year of Wonders                                        0.0  ...     NaN
# You Belong To Me                                       NaN  ...     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN  ...     NaN
# Zoya                                                   NaN  ...     NaN
# \O\" Is for Outlaw"                                    NaN  ...     NaN
#
# User-ID                                             273979  274004  274061  \
# Book-Title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     0.0     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        9.0     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   0.0     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# User-ID                                             274301  274308  275970  \
# Book-Title
# 1984                                                   NaN     NaN     0.0
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     0.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     0.0
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     0.0
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    8.0     NaN     NaN
#
# User-ID                                             277427  277639  278418
# Book-Title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     0.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# [626 rows x 809 columns]

# %%
# Fill missing values (NaNs) with 0. This means a user hasn't rated a book.
pivot_table.fillna(0, inplace=True)
pivot_table
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             2977    3363    4017    \
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        7.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             4385    6251    6323    \
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             6543    ...  271705  \
# Book-Title                                                  ...
# 1984                                                   0.0  ...    10.0
# 1st to Die: A Novel                                    9.0  ...     0.0
# 2nd Chance                                             0.0  ...     0.0
# 4 Blondes                                              0.0  ...     0.0
# A Bend in the Road                                     0.0  ...     0.0
# ...                                                    ...  ...     ...
# Year of Wonders                                        0.0  ...     0.0
# You Belong To Me                                       0.0  ...     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0  ...     0.0
# Zoya                                                   0.0  ...     0.0
# \O\" Is for Outlaw"                                    0.0  ...     0.0
#
# User-ID                                             273979  274004  274061  \
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        9.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             274301  274308  275970  \
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    8.0     0.0     0.0
#
# User-ID                                             277427  277639  278418
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# [626 rows x 809 columns]

# %%
# Convert the pivot table to a sparse matrix for efficiency
book_sparse_matrix = csr_matrix(pivot_table.values)
book_sparse_matrix
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 12731 stored elements and shape (626, 809)>

# %%
# --- Step 5: Train the Nearest Neighbors Model ---
# We will use the NearestNeighbors algorithm to find books that are "closest" to each other
# in the user-rating space.

# We use 'cosine' similarity because we care about the angle of the rating vectors, not their magnitude.
model = NearestNeighbors(algorithm='brute', metric='cosine')
model.fit(book_sparse_matrix)
model
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
# --- Step 6: Build the Recommendation Function ---
def get_collaborative_recommendations(book_title, pivot, model, n_recommendations=5):
    try:
        # Find the index of the book in the pivot table
        book_index = np.where(pivot.index == book_title)[0][0]
        
        # Find the nearest neighbors (similar books)
        distances, indices = model.kneighbors(pivot.iloc[book_index, :].values.reshape(1, -1), n_neighbors=n_recommendations + 1)
        
        print(f"\n--- Recommendations for '{book_title}' ---")
        # Loop through the recommendations, skipping the first one (the book itself)
        for i in range(1, len(distances.flatten())):
            recommended_book = pivot.index[indices.flatten()[i]]
            print(f"{i}. {recommended_book}")
            
    except IndexError:
        print(f"Book '{book_title}' not found in the filtered dataset. Please try another book.")

# %%
get_collaborative_recommendations("The Da Vinci Code", pivot_table, model)
get_collaborative_recommendations("The Hobbit", pivot_table, model)
# Out:
# --- Recommendations for 'The Da Vinci Code' ---
# 1. Angels &amp; Demons
# 2. Touching Evil
# 3. Saving Faith
# 4. Middlesex: A Novel
# 5. The Blue Nowhere : A Novel
# Book 'The Hobbit' not found in the filtered dataset. Please try another book.

# %%
# --- Step 7: Save the Model Artifacts ---
# For this model, we need to save the trained model and the pivot table (to map indices to titles).

pickle.dump(model, open('../artifacts/collaborative_model.pkl', 'wb'))
pivot_table.to_pickle('../artifacts/collaborative_pivot_table.pkl')

# %%
os.listdir('../artifacts')
# Out:
# ['tfidf_vectorizer.pkl',
#  'collaborative_model.pkl',
#  'ratings.pkl',
#  'content_df.pkl',
#  'books.pkl',
#  'users.pkl',
#  'feature_vectors.pkl',
#  'collaborative_pivot_table.pkl',
#  '.ipynb_checkpoints',
#  'popular_books.pkl']
